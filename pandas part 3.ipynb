# %%
import pandas as pd
import matplotlib as plt
world = pd.read_csv(r"/Users/adhukumara/Desktop/All course files/Python Section/2018-2019 Happiness.csv")
airbnb = pd.read_csv(r"/Users/adhukumara/Desktop/All course files/Python Section/airbnb.csv")
salaries = pd.read_csv(r"/Users/adhukumara/Desktop/All course files/Python Section/salaries.csv")
sales = pd.read_csv(r"/Users/adhukumara/Desktop/All course files/Python Section/web_sales.csv")
eth = pd.read_csv(r"/Users/adhukumara/Desktop/All course files/Python Section/Ethereum Historical Data.csv",index_col = 0)

# %%
salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8805 entries, 0 to 8804
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           8805 non-null   int64
#  1   experience_level    8805 non-null   object
#  2   employment_type     8805 non-null   object
#  3   job_title           8805 non-null   object
#  4   salary              8805 non-null   int64
#  5   salary_currency     8805 non-null   object
#  6   salary_in_usd       8805 non-null   int64
#  7   employee_residence  8805 non-null   object
#  8   remote_ratio        8805 non-null   int64
#  9   company_location    8805 non-null   object
#  10  company_size        8805 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 756.8+ KB

# %%
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30478 entries, 0 to 30477
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Host Id                     30478 non-null  int64
#  1   Host Since                  30475 non-null  object
#  2   Name                        30478 non-null  object
#  3   Neighbourhood               30478 non-null  object
#  4   Property Type               30475 non-null  object
#  5   Review Scores Rating (bin)  22155 non-null  float64
#  6   Room Type                   30478 non-null  object
#  7   Zipcode                     30344 non-null  float64
#  8   Beds                        30393 non-null  float64
#  9   Number of Records           30478 non-null  int64
#  10  Number Of Reviews           30478 non-null  int64
#  11  Price                       30478 non-null  int64
#  12  Review Scores Rating        22155 non-null  float64
# ...

# %%
airbnb.isna()#Detect missing values.
# Out:
#        Host Id  Host Since   Name  Neighbourhood  Property Type  \
# 0        False        True  False          False          False
# 1        False        True  False          False          False
# 2        False        True  False          False          False
# 3        False       False  False          False          False
# 4        False       False  False          False          False
# ...        ...         ...    ...            ...            ...
# 30473    False       False  False          False          False
# 30474    False       False  False          False          False
# 30475    False       False  False          False          False
# 30476    False       False  False          False          False
# 30477    False       False  False          False          False
#
#        Review Scores Rating (bin)  Room Type  Zipcode   Beds  \
# 0                            True      False    False  False
# 1                            True      False    False  False
# ...

# %%
airbnb.isna().sum()
# Out:
# Host Id                          0
# Host Since                       3
# Name                             0
# Neighbourhood                    0
# Property Type                    3
# Review Scores Rating (bin)    8323
# Room Type                        0
# Zipcode                        134
# Beds                            85
# Number of Records                0
# Number Of Reviews                0
# Price                            0
# Review Scores Rating          8323
# dtype: int64

# %%
airbnb['Review Scores Rating']
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4        96.0
#          ...
# 30473     NaN
# 30474     NaN
# 30475     NaN
# 30476     NaN
# 30477     NaN
# Name: Review Scores Rating, Length: 30478, dtype: float64

# %%
airbnb['Review Scores Rating'].head(20)
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4      96.0
# 5     100.0
# 6     100.0
# 7      94.0
# 8      90.0
# 9      96.0
# 10     98.0
# 11     93.0
# 12     91.0
# 13      NaN
# 14     97.0
# 15     95.0
# 16     99.0
# 17     93.0
# 18     85.0
# 19      NaN
# Name: Review Scores Rating, dtype: float64

# %%
airbnb['Review Scores Rating'].isna()
#airbnb[airbnb['Review Scores Rating'].isna()]
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 30473     True
# 30474     True
# 30475     True
# 30476     True
# 30477     True
# Name: Review Scores Rating, Length: 30478, dtype: bool

# %%
airbnb_no_reviews = airbnb[airbnb['Review Scores Rating'].isna()]

# %%
airbnb_no_reviews
# Out:
#         Host Id  Host Since                                Name Neighbourhood  \
# 0       5162530         NaN     1 Bedroom in Prime Williamsburg      Brooklyn
# 1      33134899         NaN     Sunny, Private room in Bushwick      Brooklyn
# 2      39608626         NaN                Sunny Room in Harlem     Manhattan
# 3           500  26/06/2008  Gorgeous 1 BR with Private Balcony     Manhattan
# 13         2787   7/09/2008     Renovated and spacious townhome      Brooklyn
# ...         ...         ...                                 ...           ...
# 30473  43022976  31/08/2015   10 Mins to Time Square/two floors        Queens
# 30474  42993382  31/08/2015       1BR ocean view & F,Q train st      Brooklyn
# 30475  43033067  31/08/2015                Amazing Private Room      Brooklyn
# 30476  43000991  31/08/2015   Charming private female room: UWS     Manhattan
# 30477  42999189  31/08/2015    Huge Beautiful Bedroom - Astoria        Queens
#
# ...

# %%
airbnb.notna()
# Out:
#        Host Id  Host Since  Name  Neighbourhood  Property Type  \
# 0         True       False  True           True           True
# 1         True       False  True           True           True
# 2         True       False  True           True           True
# 3         True        True  True           True           True
# 4         True        True  True           True           True
# ...        ...         ...   ...            ...            ...
# 30473     True        True  True           True           True
# 30474     True        True  True           True           True
# 30475     True        True  True           True           True
# 30476     True        True  True           True           True
# 30477     True        True  True           True           True
#
#        Review Scores Rating (bin)  Room Type  Zipcode  Beds  \
# 0                           False       True     True  True
# 1                           False       True     True  True
# ...

# %%
airbnb_reviewed = airbnb[airbnb['Review Scores Rating'].notna()]

# %%
airbnb_reviewed
# Out:
#         Host Id  Host Since                                 Name  \
# 4           500  26/06/2008             Trendy Times Square Loft
# 5          1039  25/07/2008   Big Greenpoint 1BD w/ Skyline View
# 6          1783  12/08/2008                         Amazing Also
# 7          2078  15/08/2008  Colorful, quiet, & near the subway!
# 8          2339  20/08/2008  East Village Cocoon: 2 Bedroom Flat
# ...         ...         ...                                  ...
# 30332  42349033  24/08/2015     Cute cozy studio in east village
# 30347  42430249  24/08/2015           Room in new spacious loft!
# 30378  42518458  25/08/2015   Williamsburg Luxury Loft!??Bed Top
# 30404  42697124  27/08/2015  Cute, Clean Room- East Williamsburg
# 30409  42726605  27/08/2015    Cozy and Near Tourist Attractions
#
#       Neighbourhood Property Type  Review Scores Rating (bin)  \
# 4         Manhattan     Apartment                        95.0
# ...

# %%
airbnb_non_null = airbnb.dropna()

# %%
airbnb_non_null
# Out:
#         Host Id  Host Since                                 Name  \
# 4           500  26/06/2008             Trendy Times Square Loft
# 5          1039  25/07/2008   Big Greenpoint 1BD w/ Skyline View
# 6          1783  12/08/2008                         Amazing Also
# 7          2078  15/08/2008  Colorful, quiet, & near the subway!
# 8          2339  20/08/2008  East Village Cocoon: 2 Bedroom Flat
# ...         ...         ...                                  ...
# 30332  42349033  24/08/2015     Cute cozy studio in east village
# 30347  42430249  24/08/2015           Room in new spacious loft!
# 30378  42518458  25/08/2015   Williamsburg Luxury Loft!??Bed Top
# 30404  42697124  27/08/2015  Cute, Clean Room- East Williamsburg
# 30409  42726605  27/08/2015    Cozy and Near Tourist Attractions
#
#       Neighbourhood Property Type  Review Scores Rating (bin)  \
# 4         Manhattan     Apartment                        95.0
# ...

# %%
airbnb['Zipcode'].nunique(dropna = False)
# Out:
# 189

# %%
airbnb['Neighbourhood'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Bronx', 'Staten Island'],
#       dtype=object)

# %%
airbnb['Zipcode'].unique()#gives the information about unique data
# Out:
# array([11249., 11206., 10032., 10024., 10036., 11222., 10004., 11201.,
#        10009., 11221., 10026., 11223., 10018., 11216., 10025., 11106.,
#        10001., 10013., 11365., 11220., 11373., 10002., 10038., 10027.,
#        11217., 11238., 11213., 10030., 11368., 10031., 11105., 10003.,
#        10016., 10128., 10005., 11215., 10010., 10011., 11211., 10023.,
#        10014., 11218., 10035., 10019., 11358., 11237., 11231., 11372.,
#        10451., 11205.,    nan, 10304., 10029., 10012., 11225., 10028.,
#        10281., 11233., 10039., 10033., 11434., 10280., 10075., 10021.,
#        10065., 11210., 11226., 11374., 11101., 11377., 11207., 11230.,
#        11693., 11102., 10007., 11692., 11209., 11228., 10069., 11224.,
#        11420., 11385., 11435., 11375., 10466., 10473., 10461., 11355.,
#        10022., 10017., 10454., 10040., 10044., 11234., 10034., 11103.,
#        10006., 11212., 10301., 10452., 10472., 11379., 11232., 10037.,
# ...

# %%
airbnb['Zipcode'].nunique()#nunique gives the sum of the unique data
# Out:
# 188

# %%
airbnb['Zipcode'].nunique(dropna = False)
# Out:
# 189

# %%
sales['SalesTerritoryRegion'].unique()
# Out:
# array(['Canada', 'France', 'Northwest', 'Southwest', 'Australia',
#        'United Kingdom', 'Germany', 'Southeast', 'Northeast', 'Central'],
#       dtype=object)

# %%
sales['SalesTerritoryRegion'].nunique()
# Out:
# 10

# %%
sales['product'].unique()
# Out:
# array(['Road-150 Red, 62', 'Mountain-100 Silver, 44',
#        'Road-650 Black, 62', 'Road-150 Red, 44', 'Mountain-100 Black, 48',
#        'Mountain-100 Silver, 38', 'Road-150 Red, 48', 'Road-650 Red, 52',
#        'Road-150 Red, 52', 'Road-150 Red, 56', 'Road-650 Black, 58',
#        'Mountain-100 Black, 44', 'Mountain-100 Silver, 48',
#        'Mountain-100 Silver, 42', 'Road-650 Red, 44',
#        'Road-650 Black, 52', 'Road-650 Red, 48', 'Road-650 Black, 44',
#        'Mountain-100 Black, 38', 'Mountain-100 Black, 42',
#        'Road-650 Red, 62', 'Road-650 Red, 60', 'Road-650 Black, 60',
#        'Road-650 Red, 58', 'Road-650 Black, 48', 'Road-550-W Yellow, 42',
#        'Road-250 Red, 58', 'Road-250 Black, 44', 'Mountain-200 Black, 46',
#        'Mountain-200 Black, 38', 'Mountain-200 Silver, 42',
#        'Road-550-W Yellow, 38', 'Road-250 Black, 52',
#        'Road-250 Black, 58', 'Road-250 Red, 48', 'Road-250 Red, 44',
#        'Road-250 Red, 52', 'Road-250 Black, 48',
# ...

# %%
sales['product'].nunique()
# Out:
# 130

# %%
airbnb
# Out:
#         Host Id  Host Since                                Name Neighbourhood  \
# 0       5162530         NaN     1 Bedroom in Prime Williamsburg      Brooklyn
# 1      33134899         NaN     Sunny, Private room in Bushwick      Brooklyn
# 2      39608626         NaN                Sunny Room in Harlem     Manhattan
# 3           500  26/06/2008  Gorgeous 1 BR with Private Balcony     Manhattan
# 4           500  26/06/2008            Trendy Times Square Loft     Manhattan
# ...         ...         ...                                 ...           ...
# 30473  43022976  31/08/2015   10 Mins to Time Square/two floors        Queens
# 30474  42993382  31/08/2015       1BR ocean view & F,Q train st      Brooklyn
# 30475  43033067  31/08/2015                Amazing Private Room      Brooklyn
# 30476  43000991  31/08/2015   Charming private female room: UWS     Manhattan
# 30477  42999189  31/08/2015    Huge Beautiful Bedroom - Astoria        Queens
#
# ...

# %%
airbnb['Price']
# Out:
# 0        145
# 1         37
# 2         28
# 3        199
# 4        549
#         ...
# 30473    300
# 30474    125
# 30475     80
# 30476     35
# 30477     80
# Name: Price, Length: 30478, dtype: int64

# %%
airbnb['Price'].between(100,150)
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 30473    False
# 30474     True
# 30475    False
# 30476    False
# 30477    False
# Name: Price, Length: 30478, dtype: bool

# %%
airbnb[airbnb['Price'].between(100,150)]
# Out:
#         Host Id  Host Since                                 Name  \
# 0       5162530         NaN      1 Bedroom in Prime Williamsburg
# 5          1039  25/07/2008   Big Greenpoint 1BD w/ Skyline View
# 16         2965  14/09/2008      Large Bedroom in 3-bedroom Apt.
# 17         3211  25/09/2008    Elegant NYC, 10mins to Manhattan!
# 18         3227  26/09/2008  Priv Apt,Garden,BBQ,A/C,BigTV,for 4
# ...         ...         ...                                  ...
# 30456  42952645  30/08/2015  Penthouse near Central park/Lincoln
# 30465  43008801  31/08/2015  • Sunny Artist Home in Greenpoint •
# 30467  42995294  31/08/2015   Colorful, comfortable artsy 2 bdrm
# 30469  43018396  31/08/2015   Cute East Village Studio Sept 8-16
# 30474  42993382  31/08/2015        1BR ocean view & F,Q train st
#
#       Neighbourhood Property Type  Review Scores Rating (bin)  \
# 0          Brooklyn     Apartment                         NaN
# ...

# %%
airbnb[airbnb['Beds'].between(3,5)]
# Out:
#         Host Id  Host Since                                 Name  \
# 3           500  26/06/2008   Gorgeous 1 BR with Private Balcony
# 4           500  26/06/2008             Trendy Times Square Loft
# 18         3227  26/09/2008  Priv Apt,Garden,BBQ,A/C,BigTV,for 4
# 19         3226  26/09/2008       Great 3 Bed Apt Tribeca / Soho
# 28         3867  29/10/2008    3 bedroom apartment in Chinatown!
# ...         ...         ...                                  ...
# 30445  42952645  30/08/2015  3 Beds near Central Park /Lincoln C
# 30448  42897684  30/08/2015        Comfy Couch in my Living Room
# 30449  42897684  30/08/2015     Cozy, Comfortable and Convenient
# 30467  42995294  31/08/2015   Colorful, comfortable artsy 2 bdrm
# 30473  43022976  31/08/2015    10 Mins to Time Square/two floors
#
#       Neighbourhood Property Type  Review Scores Rating (bin)  \
# 3         Manhattan     Apartment                         NaN
# ...

# %%
airbnb[airbnb['Beds'].between(3,5)]['Beds'].value_counts()
# Out:
# Beds
# 3.0    2071
# 4.0     783
# 5.0     284
# Name: count, dtype: int64

# %%
airbnb[airbnb['Price'].between(100,150) & airbnb['Beds'].between(3,5)]
# Out:
#         Host Id  Host Since                                 Name  \
# 18         3227  26/09/2008  Priv Apt,Garden,BBQ,A/C,BigTV,for 4
# 36         4488  21/11/2008           Sunny & Bright Harlem Home
# 68         7414   4/02/2009                   Skylight on Greene
# 94         8178  19/02/2009  Sunny Beautiful Sublet All Yours!!!
# 104        9744  10/03/2009   Beautiful Apt, Garden #3 Best Area
# ...         ...         ...                                  ...
# 30259  42027883  20/08/2015               Studio Near Manhattan!
# 30282  42159979  21/08/2015   Immaculate Historic Brownstone Apt
# 30316  42244283  23/08/2015      RENOVATED WINDOWED BASEMENT APT
# 30386  42602208  26/08/2015            Apartment off Forest Park
# 30467  42995294  31/08/2015   Colorful, comfortable artsy 2 bdrm
#
#        Neighbourhood Property Type  Review Scores Rating (bin)  \
# 18         Manhattan     Apartment                        85.0
# ...

# %%
airbnb[(airbnb['Property Type'] == 'Apartment') & (airbnb['Neighbourhood'] == 'Brooklyn')]
# Out:
#         Host Id  Host Since                                 Name  \
# 0       5162530         NaN      1 Bedroom in Prime Williamsburg
# 1      33134899         NaN      Sunny, Private room in Bushwick
# 5          1039  25/07/2008   Big Greenpoint 1BD w/ Skyline View
# 7          2078  15/08/2008  Colorful, quiet, & near the subway!
# 10         2571  27/08/2008                           THE PUTNAM
# ...         ...         ...                                  ...
# 30464  42990630  31/08/2015   Lovely and large Williamsburg Loft
# 30465  43008801  31/08/2015  • Sunny Artist Home in Greenpoint •
# 30466  42997784  31/08/2015        Beautiful parkfront sanctuary
# 30467  42995294  31/08/2015   Colorful, comfortable artsy 2 bdrm
# 30474  42993382  31/08/2015        1BR ocean view & F,Q train st
#
#       Neighbourhood Property Type  Review Scores Rating (bin)  \
# 0          Brooklyn     Apartment                         NaN
# ...

# %%
airbnb[(airbnb['Property Type'] == 'Apartment') & (airbnb['Neighbourhood'] == 'Brooklyn') & (airbnb['Price'] < 100)]
# Out:
#         Host Id  Host Since                                 Name  \
# 1      33134899         NaN      Sunny, Private room in Bushwick
# 7          2078  15/08/2008  Colorful, quiet, & near the subway!
# 15         2881  10/09/2008  Newly renovated historic brownstone
# 23         3563  10/10/2008  16' x 11' Furnished BR with Balcony
# 64         7356   3/02/2009                      BlissArtsSpace!
# ...         ...         ...                                  ...
# 30433  42867270  29/08/2015       Cozy Room in Downtown Brooklyn
# 30450  42949529  30/08/2015     Quiet and nice room in Brooklyn.
# 30451  42911814  30/08/2015         Spacious Quiet Tranquil Room
# 30452  42926593  30/08/2015     Beautiful Loft East Williamsburg
# 30453  42932564  30/08/2015          Large Room - Sunny and New!
#
#       Neighbourhood Property Type  Review Scores Rating (bin)     Room Type  \
# 1          Brooklyn     Apartment                         NaN  Private room
# ...

# %%
salaries
# Out:
#       work_year experience_level employment_type  \
# 0          2023               EX              FT
# 1          2023               EX              FT
# 2          2023               MI              FT
# 3          2023               MI              FT
# 4          2023               SE              FT
# ...         ...              ...             ...
# 8800       2020               SE              FT
# 8801       2021               MI              FT
# 8802       2020               EN              FT
# 8803       2020               EN              CT
# 8804       2021               SE              FT
#
#                            job_title   salary salary_currency  salary_in_usd  \
# 0              Data Science Director   212000             USD         212000
# 1              Data Science Director   190000             USD         190000
# 2     Business Intelligence Engineer    35000             GBP          43064
# ...

# %%
salaries['job_title']
# Out:
# 0                Data Science Director
# 1                Data Science Director
# 2       Business Intelligence Engineer
# 3       Business Intelligence Engineer
# 4            Machine Learning Engineer
#                      ...
# 8800                    Data Scientist
# 8801          Principal Data Scientist
# 8802                    Data Scientist
# 8803             Business Data Analyst
# 8804              Data Science Manager
# Name: job_title, Length: 8805, dtype: object

# %%
salaries['job_title'].value_counts()
# Out:
# job_title
# Data Engineer                     2062
# Data Scientist                    1852
# Data Analyst                      1322
# Machine Learning Engineer          908
# Applied Scientist                  258
#                                   ...
# Deep Learning Researcher             1
# Consultant Data Engineer             1
# BI Data Engineer                     1
# Managing Director Data Science       1
# AWS Data Architect                   1
# Name: count, Length: 124, dtype: int64

# %%
salaries[salaries['job_title'] == 'Data Engineer']
#Data Analyst
# Out:
#       work_year experience_level employment_type      job_title  salary  \
# 14         2023               MI              FT  Data Engineer  133000
# 15         2023               MI              FT  Data Engineer   58300
# 18         2023               SE              FT  Data Engineer  300000
# 19         2023               SE              FT  Data Engineer  195000
# 50         2023               SE              FT  Data Engineer  205500
# ...         ...              ...             ...            ...     ...
# 8763       2020               MI              FT  Data Engineer  110000
# 8768       2021               SE              FT  Data Engineer   65000
# 8789       2021               MI              FT  Data Engineer   38400
# 8793       2020               MI              FT  Data Engineer  130800
# 8798       2021               MI              FT  Data Engineer   24000
#
#      salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %%
salaries[(salaries['job_title'] == 'Data Engineer')|(salaries['job_title']=='Data Analyst')]
# Out:
#       work_year experience_level employment_type      job_title  salary  \
# 14         2023               MI              FT  Data Engineer  133000
# 15         2023               MI              FT  Data Engineer   58300
# 16         2023               SE              FT   Data Analyst  145640
# 17         2023               SE              FT   Data Analyst   84400
# 18         2023               SE              FT  Data Engineer  300000
# ...         ...              ...             ...            ...     ...
# 8786       2021               MI              FT   Data Analyst   75000
# 8787       2021               MI              FT   Data Analyst   62000
# 8789       2021               MI              FT  Data Engineer   38400
# 8793       2020               MI              FT  Data Engineer  130800
# 8798       2021               MI              FT  Data Engineer   24000
#
#      salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %%
salaries[(salaries['job_title'] == 'Data Engineer')|(salaries['job_title']=='Data Analyst') & (salaries['salary_in_usd']>200000)]
# Out:
#       work_year experience_level employment_type      job_title  salary  \
# 14         2023               MI              FT  Data Engineer  133000
# 15         2023               MI              FT  Data Engineer   58300
# 18         2023               SE              FT  Data Engineer  300000
# 19         2023               SE              FT  Data Engineer  195000
# 50         2023               SE              FT  Data Engineer  205500
# ...         ...              ...             ...            ...     ...
# 8763       2020               MI              FT  Data Engineer  110000
# 8768       2021               SE              FT  Data Engineer   65000
# 8789       2021               MI              FT  Data Engineer   38400
# 8793       2020               MI              FT  Data Engineer  130800
# 8798       2021               MI              FT  Data Engineer   24000
#
#      salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %%
salaries[((salaries['job_title'] == 'Data Engineer')|(salaries['job_title']=='Data Analyst')) & (salaries['salary_in_usd']>200000)]
# Out:
#       work_year experience_level employment_type      job_title  salary  \
# 18         2023               SE              FT  Data Engineer  300000
# 50         2023               SE              FT  Data Engineer  205500
# 66         2023               SE              FT  Data Engineer  300000
# 68         2023               MI              FT  Data Engineer  210500
# 114        2023               SE              FT  Data Engineer  266875
# ...         ...              ...             ...            ...     ...
# 8418       2022               MI              FT  Data Engineer  206699
# 8458       2022               SE              FT  Data Engineer  220110
# 8478       2022               EX              FT  Data Engineer  324000
# 8479       2022               EX              FT  Data Engineer  216000
# 8480       2022               SE              FT  Data Engineer  210000
#
#      salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %%
salaries[((salaries['job_title'] == 'Data Engineer')
          |(salaries['job_title']=='Data Analyst'))
          & (salaries['salary_in_usd']>200000)]['job_title'].value_counts()
# Out:
# job_title
# Data Engineer    336
# Data Analyst      38
# Name: count, dtype: int64

# %%
salaries[((salaries['job_title'].isin(['Data Engineer','Data Analyst','Data Scientist']))
          |(salaries['job_title']=='Data Analyst'))
          & (salaries['salary_in_usd']>200000)]['job_title'].value_counts()
# Out:
# job_title
# Data Scientist    377
# Data Engineer     336
# Data Analyst       38
# Name: count, dtype: int64

# %%
salaries[salaries['job_title'].isin(['Data Engineer','Data Analyst','Data Scientist'])]
# Out:
#       work_year experience_level employment_type       job_title  salary  \
# 10         2023               MI              FT  Data Scientist  212000
# 11         2023               MI              FT  Data Scientist   93300
# 14         2023               MI              FT   Data Engineer  133000
# 15         2023               MI              FT   Data Engineer   58300
# 16         2023               SE              FT    Data Analyst  145640
# ...         ...              ...             ...             ...     ...
# 8793       2020               MI              FT   Data Engineer  130800
# 8796       2021               MI              FT  Data Scientist  160000
# 8798       2021               MI              FT   Data Engineer   24000
# 8800       2020               SE              FT  Data Scientist  412000
# 8802       2020               EN              FT  Data Scientist  105000
#
#      salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %%
airbnb
# Out:
#         Host Id  Host Since                                Name Neighbourhood  \
# 0       5162530         NaN     1 Bedroom in Prime Williamsburg      Brooklyn
# 1      33134899         NaN     Sunny, Private room in Bushwick      Brooklyn
# 2      39608626         NaN                Sunny Room in Harlem     Manhattan
# 3           500  26/06/2008  Gorgeous 1 BR with Private Balcony     Manhattan
# 4           500  26/06/2008            Trendy Times Square Loft     Manhattan
# ...         ...         ...                                 ...           ...
# 30473  43022976  31/08/2015   10 Mins to Time Square/two floors        Queens
# 30474  42993382  31/08/2015       1BR ocean view & F,Q train st      Brooklyn
# 30475  43033067  31/08/2015                Amazing Private Room      Brooklyn
# 30476  43000991  31/08/2015   Charming private female room: UWS     Manhattan
# 30477  42999189  31/08/2015    Huge Beautiful Bedroom - Astoria        Queens
#
# ...

# %%
airbnb['Property Type']
# Out:
# 0        Apartment
# 1        Apartment
# 2        Apartment
# 3        Apartment
# 4        Apartment
#            ...
# 30473    Apartment
# 30474    Apartment
# 30475        Other
# 30476    Apartment
# 30477        House
# Name: Property Type, Length: 30478, dtype: object

# %%
apartments_and_lofts = airbnb[airbnb['Property Type'].isin(['Apartment', 'Loft'])]
everything_else = airbnb[~airbnb['Property Type'].isin(['Apartment', 'Loft'])]

# %%
apartments_and_lofts
# Out:
#         Host Id  Host Since                                 Name  \
# 0       5162530         NaN      1 Bedroom in Prime Williamsburg
# 1      33134899         NaN      Sunny, Private room in Bushwick
# 2      39608626         NaN                 Sunny Room in Harlem
# 3           500  26/06/2008   Gorgeous 1 BR with Private Balcony
# 4           500  26/06/2008             Trendy Times Square Loft
# ...         ...         ...                                  ...
# 30471  42959506  31/08/2015  Time Square! 2 Fully Furnished apt.
# 30472  43007478  31/08/2015    Luxury apt with spectacular views
# 30473  43022976  31/08/2015    10 Mins to Time Square/two floors
# 30474  42993382  31/08/2015        1BR ocean view & F,Q train st
# 30476  43000991  31/08/2015    Charming private female room: UWS
#
#       Neighbourhood Property Type  Review Scores Rating (bin)  \
# 0          Brooklyn     Apartment                         NaN
# ...

# %%
everything_else
# Out:
#         Host Id  Host Since                                 Name  \
# 13         2787   7/09/2008      Renovated and spacious townhome
# 22         3415   2/10/2008   Beautiful Furnished Master Bedroom
# 38         4869   7/12/2008   Whole B'stone flr w priv kit & bat
# 50         5926   2/01/2009   Nice  Apt Near Columbia University
# 101        8730  27/02/2009                Comfort & Convenience
# ...         ...         ...                                  ...
# 30438  42920207  30/08/2015                    Terrace Apartment
# 30447  42886451  30/08/2015   Flushing Meadows NY Spacious House
# 30461  42917787  30/08/2015  East Village,  First floor.  new bg
# 30475  43033067  31/08/2015                 Amazing Private Room
# 30477  42999189  31/08/2015     Huge Beautiful Bedroom - Astoria
#
#       Neighbourhood    Property Type  Review Scores Rating (bin)  \
# 13         Brooklyn            House                         NaN
# ...

# %%
airbnb['city']='New York'

# %%
airbnb
# Out:
#         Host Id  Host Since                                Name Neighbourhood  \
# 0       5162530         NaN     1 Bedroom in Prime Williamsburg      Brooklyn
# 1      33134899         NaN     Sunny, Private room in Bushwick      Brooklyn
# 2      39608626         NaN                Sunny Room in Harlem     Manhattan
# 3           500  26/06/2008  Gorgeous 1 BR with Private Balcony     Manhattan
# 4           500  26/06/2008            Trendy Times Square Loft     Manhattan
# ...         ...         ...                                 ...           ...
# 30473  43022976  31/08/2015   10 Mins to Time Square/two floors        Queens
# 30474  42993382  31/08/2015       1BR ocean view & F,Q train st      Brooklyn
# 30475  43033067  31/08/2015                Amazing Private Room      Brooklyn
# 30476  43000991  31/08/2015   Charming private female room: UWS     Manhattan
# 30477  42999189  31/08/2015    Huge Beautiful Bedroom - Astoria        Queens
#
# ...

# %%
airbnb.drop(labels = 'city', axis = 1 ,inplace =True)

# %%
airbnb
# Out:
#         Host Id  Host Since                                Name Neighbourhood  \
# 0       5162530         NaN     1 Bedroom in Prime Williamsburg      Brooklyn
# 1      33134899         NaN     Sunny, Private room in Bushwick      Brooklyn
# 2      39608626         NaN                Sunny Room in Harlem     Manhattan
# 3           500  26/06/2008  Gorgeous 1 BR with Private Balcony     Manhattan
# 4           500  26/06/2008            Trendy Times Square Loft     Manhattan
# ...         ...         ...                                 ...           ...
# 30473  43022976  31/08/2015   10 Mins to Time Square/two floors        Queens
# 30474  42993382  31/08/2015       1BR ocean view & F,Q train st      Brooklyn
# 30475  43033067  31/08/2015                Amazing Private Room      Brooklyn
# 30476  43000991  31/08/2015   Charming private female room: UWS     Manhattan
# 30477  42999189  31/08/2015    Huge Beautiful Bedroom - Astoria        Queens
#
# ...

# %%
airbnb['Number of Records'].value_counts()
# Out:
# Number of Records
# 1    30478
# Name: count, dtype: int64

# %%
airbnb.drop(labels = 'Number of Records', axis = 1 ,inplace =True)

# %%
airbnb
# Out:
#         Host Id  Host Since                                Name Neighbourhood  \
# 0       5162530         NaN     1 Bedroom in Prime Williamsburg      Brooklyn
# 1      33134899         NaN     Sunny, Private room in Bushwick      Brooklyn
# 2      39608626         NaN                Sunny Room in Harlem     Manhattan
# 3           500  26/06/2008  Gorgeous 1 BR with Private Balcony     Manhattan
# 4           500  26/06/2008            Trendy Times Square Loft     Manhattan
# ...         ...         ...                                 ...           ...
# 30473  43022976  31/08/2015   10 Mins to Time Square/two floors        Queens
# 30474  42993382  31/08/2015       1BR ocean view & F,Q train st      Brooklyn
# 30475  43033067  31/08/2015                Amazing Private Room      Brooklyn
# 30476  43000991  31/08/2015   Charming private female room: UWS     Manhattan
# 30477  42999189  31/08/2015    Huge Beautiful Bedroom - Astoria        Queens
#
# ...

# %%
sales['Sales with Tax and Freight'] = sales['SalesAmount'] + sales['TaxAmt'] + sales['Freight']

# %%
sales
# Out:
#        ProductKey                  product product_subcategory  OrderDateKey  \
# 0             310         Road-150 Red, 62          Road Bikes      20101229
# 1             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 2             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 3             336       Road-650 Black, 62          Road Bikes      20101229
# 4             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# ...           ...                      ...                 ...           ...
# 60393         485    Fender Set - Mountain             Fenders      20140128
# 60394         225             AWC Logo Cap                Caps      20140128
# 60395         485    Fender Set - Mountain             Fenders      20140128
# 60396         486   All-Purpose Bike Stand         Bike Stands      20140128
# 60397         225             AWC Logo Cap                Caps      20140128
#
# ...

# %%
eth
# Out:
#            Coin    Price     Open     High      Low     Vol. Change %
# Date
# 10/02/2024  ETH  2508.31  2486.24  2514.83  2483.50  504.80K    0.89%
# 9/02/2024   ETH  2486.24  2419.56  2522.96  2419.16  540.92K    2.76%
# 8/02/2024   ETH  2419.56  2424.66  2461.00  2412.01  350.33K   -0.21%
# 7/02/2024   ETH  2424.64  2372.65  2443.71  2354.46  355.40K    2.19%
# 6/02/2024   ETH  2372.65  2301.83  2390.53  2299.24  381.23K    3.08%
# ...         ...      ...      ...      ...      ...      ...      ...
# 5/01/2020   ETH   135.59   134.32   138.33   134.32   12.19M    0.94%
# 4/01/2020   ETH   134.33   134.30   135.57   132.76   11.16M    0.04%
# 3/01/2020   ETH   134.27   127.19   134.86   126.05   15.67M    5.56%
# 2/01/2020   ETH   127.19   130.75   130.77   126.74   11.45M   -2.72%
# 1/01/2020   ETH   130.75   129.21   132.97   128.81   10.35M    1.19%
#
# [1502 rows x 7 columns]

# %%
eth['voltatility'] = eth['High'] - eth['Low']

# %%
eth
# Out:
#            Coin    Price     Open     High      Low     Vol. Change %  \
# Date
# 10/02/2024  ETH  2508.31  2486.24  2514.83  2483.50  504.80K    0.89%
# 9/02/2024   ETH  2486.24  2419.56  2522.96  2419.16  540.92K    2.76%
# 8/02/2024   ETH  2419.56  2424.66  2461.00  2412.01  350.33K   -0.21%
# 7/02/2024   ETH  2424.64  2372.65  2443.71  2354.46  355.40K    2.19%
# 6/02/2024   ETH  2372.65  2301.83  2390.53  2299.24  381.23K    3.08%
# ...         ...      ...      ...      ...      ...      ...      ...
# 5/01/2020   ETH   135.59   134.32   138.33   134.32   12.19M    0.94%
# 4/01/2020   ETH   134.33   134.30   135.57   132.76   11.16M    0.04%
# 3/01/2020   ETH   134.27   127.19   134.86   126.05   15.67M    5.56%
# 2/01/2020   ETH   127.19   130.75   130.77   126.74   11.45M   -2.72%
# 1/01/2020   ETH   130.75   129.21   132.97   128.81   10.35M    1.19%
#
#             voltatility
# Date
# 10/02/2024        31.33
# 9/02/2024        103.80
# 8/02/2024         48.99
# ...

# %%
sales
# Out:
#        ProductKey                  product product_subcategory  OrderDateKey  \
# 0             310         Road-150 Red, 62          Road Bikes      20101229
# 1             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 2             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 3             336       Road-650 Black, 62          Road Bikes      20101229
# 4             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# ...           ...                      ...                 ...           ...
# 60393         485    Fender Set - Mountain             Fenders      20140128
# 60394         225             AWC Logo Cap                Caps      20140128
# 60395         485    Fender Set - Mountain             Fenders      20140128
# 60396         486   All-Purpose Bike Stand         Bike Stands      20140128
# 60397         225             AWC Logo Cap                Caps      20140128
#
# ...

# %%
sales['Sales Type'] = sales['product_subcategory']  + sales['SalesTerritoryCountry']

# %%
sales
# Out:
#        ProductKey                  product product_subcategory  OrderDateKey  \
# 0             310         Road-150 Red, 62          Road Bikes      20101229
# 1             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 2             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 3             336       Road-650 Black, 62          Road Bikes      20101229
# 4             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# ...           ...                      ...                 ...           ...
# 60393         485    Fender Set - Mountain             Fenders      20140128
# 60394         225             AWC Logo Cap                Caps      20140128
# 60395         485    Fender Set - Mountain             Fenders      20140128
# 60396         486   All-Purpose Bike Stand         Bike Stands      20140128
# 60397         225             AWC Logo Cap                Caps      20140128
#
# ...

# %%
sales['Sales Type'] = sales['product_subcategory'] + ' in ' + sales['SalesTerritoryCountry']

# %%
sales
# Out:
#        ProductKey                  product product_subcategory  OrderDateKey  \
# 0             310         Road-150 Red, 62          Road Bikes      20101229
# 1             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 2             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 3             336       Road-650 Black, 62          Road Bikes      20101229
# 4             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# ...           ...                      ...                 ...           ...
# 60393         485    Fender Set - Mountain             Fenders      20140128
# 60394         225             AWC Logo Cap                Caps      20140128
# 60395         485    Fender Set - Mountain             Fenders      20140128
# 60396         486   All-Purpose Bike Stand         Bike Stands      20140128
# 60397         225             AWC Logo Cap                Caps      20140128
#
# ...
