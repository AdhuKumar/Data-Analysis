# %% [markdown]
# # IMPORT PANDAS AND MATPLOTLIB

# %%
import pandas as pd
import matplotlib as plt

# %% [markdown]
# # READ CSV

# %%
world = pd.read_csv(r"/Users/adhukumara/Desktop/All course files/Python Section/2018-2019 Happiness.csv")
airbnb = pd.read_csv(r"/Users/adhukumara/Desktop/All course files/Python Section/airbnb.csv")
salaries = pd.read_csv(r"/Users/adhukumara/Desktop/All course files/Python Section/salaries.csv")
sales = pd.read_csv(r"/Users/adhukumara/Desktop/All course files/Python Section/web_sales.csv")

# %%
world
# Out:
#      Overall rank  Year         Country or region  Score  GDP per capita  \
# 0               1  2019                   Finland  7.769           1.340
# 1               2  2019                   Denmark  7.600           1.383
# 2               3  2019                    Norway  7.554           1.488
# 3               4  2019                   Iceland  7.494           1.380
# 4               5  2019               Netherlands  7.488           1.396
# ..            ...   ...                       ...    ...             ...
# 307           152  2018                     Yemen  3.355           0.442
# 308           153  2018                  Tanzania  3.303           0.455
# 309           154  2018               South Sudan  3.254           0.337
# 310           155  2018  Central African Republic  3.083           0.024
# 311           156  2018                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# ...

# %%
airbnb
# Out:
#         Host Id  Host Since                                Name Neighbourhood  \
# 0       5162530         NaN     1 Bedroom in Prime Williamsburg      Brooklyn
# 1      33134899         NaN     Sunny, Private room in Bushwick      Brooklyn
# 2      39608626         NaN                Sunny Room in Harlem     Manhattan
# 3           500  26/06/2008  Gorgeous 1 BR with Private Balcony     Manhattan
# 4           500  26/06/2008            Trendy Times Square Loft     Manhattan
# ...         ...         ...                                 ...           ...
# 30473  43022976  31/08/2015   10 Mins to Time Square/two floors        Queens
# 30474  42993382  31/08/2015       1BR ocean view & F,Q train st      Brooklyn
# 30475  43033067  31/08/2015                Amazing Private Room      Brooklyn
# 30476  43000991  31/08/2015   Charming private female room: UWS     Manhattan
# 30477  42999189  31/08/2015    Huge Beautiful Bedroom - Astoria        Queens
#
# ...

# %%
world.head(10)#first 10 row will be shown
# Out:
#    Overall rank  Year Country or region  Score  GDP per capita  \
# 0             1  2019           Finland  7.769           1.340
# 1             2  2019           Denmark  7.600           1.383
# 2             3  2019            Norway  7.554           1.488
# 3             4  2019           Iceland  7.494           1.380
# 4             5  2019       Netherlands  7.488           1.396
# 5             6  2019       Switzerland  7.480           1.452
# 6             7  2019            Sweden  7.343           1.387
# 7             8  2019       New Zealand  7.307           1.303
# 8             9  2019            Canada  7.278           1.365
# 9            10  2019           Austria  7.246           1.376
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0           1.587                    0.986                         0.596
# 1           1.573                    0.996                         0.592
# ...

# %%
world.tail(10)#last 10 row will be shown
# Out:
#      Overall rank  Year         Country or region  Score  GDP per capita  \
# 302           147  2018                    Malawi  3.587           0.186
# 303           148  2018                     Haiti  3.582           0.315
# 304           149  2018                   Liberia  3.495           0.076
# 305           150  2018                     Syria  3.462           0.689
# 306           151  2018                    Rwanda  3.408           0.332
# 307           152  2018                     Yemen  3.355           0.442
# 308           153  2018                  Tanzania  3.303           0.455
# 309           154  2018               South Sudan  3.254           0.337
# 310           155  2018  Central African Republic  3.083           0.024
# 311           156  2018                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 302           0.541                    0.306                         0.531
# ...

# %%
world.columns
# Out:
# Index(['Overall rank', 'Year', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
airbnb.head()#first 4 rows should be shown at random if any range is not specified in bracket
# Out:
#     Host Id  Host Since                                Name Neighbourhood  \
# 0   5162530         NaN     1 Bedroom in Prime Williamsburg      Brooklyn
# 1  33134899         NaN     Sunny, Private room in Bushwick      Brooklyn
# 2  39608626         NaN                Sunny Room in Harlem     Manhattan
# 3       500  26/06/2008  Gorgeous 1 BR with Private Balcony     Manhattan
# 4       500  26/06/2008            Trendy Times Square Loft     Manhattan
#
#   Property Type  Review Scores Rating (bin)        Room Type  Zipcode  Beds  \
# 0     Apartment                         NaN  Entire home/apt  11249.0   1.0
# 1     Apartment                         NaN     Private room  11206.0   1.0
# 2     Apartment                         NaN     Private room  10032.0   1.0
# 3     Apartment                         NaN  Entire home/apt  10024.0   3.0
# 4     Apartment                        95.0     Private room  10036.0   3.0
#
# ...

# %%
salaries
# Out:
#       work_year experience_level employment_type  \
# 0          2023               EX              FT
# 1          2023               EX              FT
# 2          2023               MI              FT
# 3          2023               MI              FT
# 4          2023               SE              FT
# ...         ...              ...             ...
# 8800       2020               SE              FT
# 8801       2021               MI              FT
# 8802       2020               EN              FT
# 8803       2020               EN              CT
# 8804       2021               SE              FT
#
#                            job_title   salary salary_currency  salary_in_usd  \
# 0              Data Science Director   212000             USD         212000
# 1              Data Science Director   190000             USD         190000
# 2     Business Intelligence Engineer    35000             GBP          43064
# ...

# %%
sales
# Out:
#        ProductKey                  product product_subcategory  OrderDateKey  \
# 0             310         Road-150 Red, 62          Road Bikes      20101229
# 1             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 2             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 3             336       Road-650 Black, 62          Road Bikes      20101229
# 4             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# ...           ...                      ...                 ...           ...
# 60393         485    Fender Set - Mountain             Fenders      20140128
# 60394         225             AWC Logo Cap                Caps      20140128
# 60395         485    Fender Set - Mountain             Fenders      20140128
# 60396         486   All-Purpose Bike Stand         Bike Stands      20140128
# 60397         225             AWC Logo Cap                Caps      20140128
#
# ...

# %%
salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8805 entries, 0 to 8804
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           8805 non-null   int64
#  1   experience_level    8805 non-null   object
#  2   employment_type     8805 non-null   object
#  3   job_title           8805 non-null   object
#  4   salary              8805 non-null   int64
#  5   salary_currency     8805 non-null   object
#  6   salary_in_usd       8805 non-null   int64
#  7   employee_residence  8805 non-null   object
#  8   remote_ratio        8805 non-null   int64
#  9   company_location    8805 non-null   object
#  10  company_size        8805 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 756.8+ KB

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60398 entries, 0 to 60397
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ProductKey             60398 non-null  int64
#  1   product                60398 non-null  object
#  2   product_subcategory    60398 non-null  object
#  3   OrderDateKey           60398 non-null  int64
#  4   CalendarYear           60398 non-null  int64
#  5   SalesTerritoryRegion   60398 non-null  object
#  6   SalesTerritoryCountry  60398 non-null  object
#  7   SalesOrderNumber       60398 non-null  object
#  8   SalesAmount            60398 non-null  float64
#  9   TaxAmt                 60398 non-null  float64
#  10  Freight                60398 non-null  float64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 5.1+ MB

# %%
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30478 entries, 0 to 30477
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Host Id                     30478 non-null  int64
#  1   Host Since                  30475 non-null  object
#  2   Name                        30478 non-null  object
#  3   Neighbourhood               30478 non-null  object
#  4   Property Type               30475 non-null  object
#  5   Review Scores Rating (bin)  22155 non-null  float64
#  6   Room Type                   30478 non-null  object
#  7   Zipcode                     30344 non-null  float64
#  8   Beds                        30393 non-null  float64
#  9   Number of Records           30478 non-null  int64
#  10  Number Of Reviews           30478 non-null  int64
#  11  Price                       30478 non-null  int64
#  12  Review Scores Rating        22155 non-null  float64
# ...

# %%
airbnb.dtypes
# Out:
# Host Id                         int64
# Host Since                     object
# Name                           object
# Neighbourhood                  object
# Property Type                  object
# Review Scores Rating (bin)    float64
# Room Type                      object
# Zipcode                       float64
# Beds                          float64
# Number of Records               int64
# Number Of Reviews               int64
# Price                           int64
# Review Scores Rating          float64
# dtype: object

# %%
salaries.shape
# Out:
# (8805, 11)

# %%
salaries.size
# Out:
# 96855

# %%
airbnb.shape
# Out:
# (30478, 13)

# %%
airbnb.size
# Out:
# 396214

# %%
airbnb.columns
# Out:
# Index(['Host Id', 'Host Since', 'Name', 'Neighbourhood', 'Property Type',
#        'Review Scores Rating (bin)', 'Room Type', 'Zipcode', 'Beds',
#        'Number of Records', 'Number Of Reviews', 'Price',
#        'Review Scores Rating'],
#       dtype='object')

# %%
columns = ['host Id', 'host Since', 'Name', 'Neighbourhood', 'Property Type',
       'Review Scores Rating (bin)', 'Room Type', 'Zipcode', 'Beds',
       'Number of Records', 'Number Of Reviews', 'Price',
       'Review Scores Rating']

# %%
columns
# Out:
# ['host Id',
#  'host Since',
#  'Name',
#  'Neighbourhood',
#  'Property Type',
#  'Review Scores Rating (bin)',
#  'Room Type',
#  'Zipcode',
#  'Beds',
#  'Number of Records',
#  'Number Of Reviews',
#  'Price',
#  'Review Scores Rating']

# %%
airbnb = pd.read_csv(r"/Users/adhukumara/Desktop/All course files/Python Section/airbnb.csv",names = columns, header = 0)

# %%
airbnb
# Out:
#         Host Id  Host Since                                Name  \
# 0       Host Id  Host Since                                Name
# 1       5162530         NaN     1 Bedroom in Prime Williamsburg
# 2      33134899         NaN     Sunny, Private room in Bushwick
# 3      39608626         NaN                Sunny Room in Harlem
# 4           500  26/06/2008  Gorgeous 1 BR with Private Balcony
# ...         ...         ...                                 ...
# 30474  43022976  31/08/2015   10 Mins to Time Square/two floors
# 30475  42993382  31/08/2015       1BR ocean view & F,Q train st
# 30476  43033067  31/08/2015                Amazing Private Room
# 30477  43000991  31/08/2015   Charming private female room: UWS
# 30478  42999189  31/08/2015    Huge Beautiful Bedroom - Astoria
#
#        Neighbourhood  Property Type  Review Scores Rating (bin)  \
# 0      Neighbourhood  Property Type  Review Scores Rating (bin)
# 1           Brooklyn      Apartment                         NaN
# ...

# %%
sales
# Out:
#        ProductKey                  product product_subcategory  OrderDateKey  \
# 0             310         Road-150 Red, 62          Road Bikes      20101229
# 1             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 2             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 3             336       Road-650 Black, 62          Road Bikes      20101229
# 4             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# ...           ...                      ...                 ...           ...
# 60393         485    Fender Set - Mountain             Fenders      20140128
# 60394         225             AWC Logo Cap                Caps      20140128
# 60395         485    Fender Set - Mountain             Fenders      20140128
# 60396         486   All-Purpose Bike Stand         Bike Stands      20140128
# 60397         225             AWC Logo Cap                Caps      20140128
#
# ...

# %%
sales
# Out:
#        ProductKey                  product product_subcategory  OrderDateKey  \
# 0             310         Road-150 Red, 62          Road Bikes      20101229
# 1             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 2             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 3             336       Road-650 Black, 62          Road Bikes      20101229
# 4             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# ...           ...                      ...                 ...           ...
# 60393         485    Fender Set - Mountain             Fenders      20140128
# 60394         225             AWC Logo Cap                Caps      20140128
# 60395         485    Fender Set - Mountain             Fenders      20140128
# 60396         486   All-Purpose Bike Stand         Bike Stands      20140128
# 60397         225             AWC Logo Cap                Caps      20140128
#
# ...

# %%
columns_sales = ['ProductKey', 'product', 'product_subcategory', 'OrderDateKey',
       'CalendarYear', 'SalesTerritoryRegion', 'SalesTerritoryCountry',
       'SalesOrderNumber', 'SalesAmount', 'TaxAmt', 'Freight']

# %%
sales = pd.read_csv(r"/Users/adhukumara/Desktop/All course files/Python Section/web_sales.csv",names =columns_sales, header = 0)

# %%
sales
# Out:
#        ProductKey                  product product_subcategory  OrderDateKey  \
# 0             310         Road-150 Red, 62          Road Bikes      20101229
# 1             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 2             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 3             336       Road-650 Black, 62          Road Bikes      20101229
# 4             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# ...           ...                      ...                 ...           ...
# 60393         485    Fender Set - Mountain             Fenders      20140128
# 60394         225             AWC Logo Cap                Caps      20140128
# 60395         485    Fender Set - Mountain             Fenders      20140128
# 60396         486   All-Purpose Bike Stand         Bike Stands      20140128
# 60397         225             AWC Logo Cap                Caps      20140128
#
# ...
