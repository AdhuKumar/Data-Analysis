# %%
import pandas as pd
import matplotlib as plt
world = pd.read_csv(r"/Users/adhukumara/Desktop/All course files/Python Section/2018-2019 Happiness.csv")
airbnb = pd.read_csv(r"/Users/adhukumara/Desktop/All course files/Python Section/airbnb.csv")
salaries = pd.read_csv(r"/Users/adhukumara/Desktop/All course files/Python Section/salaries.csv")
sales = pd.read_csv(r"/Users/adhukumara/Desktop/All course files/Python Section/web_sales.csv")
eth = pd.read_csv(r"/Users/adhukumara/Desktop/All course files/Python Section/Ethereum Historical Data.csv",index_col = 0)

# %%
eth.index
# Out:
# Index(['10/02/2024', '9/02/2024', '8/02/2024', '7/02/2024', '6/02/2024',
#        '5/02/2024', '4/02/2024', '3/02/2024', '2/02/2024', '1/02/2024',
#        ...
#        '10/01/2020', '9/01/2020', '8/01/2020', '7/01/2020', '6/01/2020',
#        '5/01/2020', '4/01/2020', '3/01/2020', '2/01/2020', '1/01/2020'],
#       dtype='object', name='Date', length=1502)

# %%
eth
# Out:
#            Coin    Price     Open     High      Low     Vol. Change %
# Date
# 10/02/2024  ETH  2508.31  2486.24  2514.83  2483.50  504.80K    0.89%
# 9/02/2024   ETH  2486.24  2419.56  2522.96  2419.16  540.92K    2.76%
# 8/02/2024   ETH  2419.56  2424.66  2461.00  2412.01  350.33K   -0.21%
# 7/02/2024   ETH  2424.64  2372.65  2443.71  2354.46  355.40K    2.19%
# 6/02/2024   ETH  2372.65  2301.83  2390.53  2299.24  381.23K    3.08%
# ...         ...      ...      ...      ...      ...      ...      ...
# 5/01/2020   ETH   135.59   134.32   138.33   134.32   12.19M    0.94%
# 4/01/2020   ETH   134.33   134.30   135.57   132.76   11.16M    0.04%
# 3/01/2020   ETH   134.27   127.19   134.86   126.05   15.67M    5.56%
# 2/01/2020   ETH   127.19   130.75   130.77   126.74   11.45M   -2.72%
# 1/01/2020   ETH   130.75   129.21   132.97   128.81   10.35M    1.19%
#
# [1502 rows x 7 columns]

# %%
eth.reset_index(inplace=True)

# %%
eth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1502 entries, 0 to 1501
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1502 non-null   object
#  1   Coin      1502 non-null   object
#  2   Price     1502 non-null   float64
#  3   Open      1502 non-null   float64
#  4   High      1502 non-null   float64
#  5   Low       1502 non-null   float64
#  6   Vol.      1502 non-null   object
#  7   Change %  1502 non-null   object
# dtypes: float64(4), object(4)
# memory usage: 94.0+ KB

# %%
eth.set_index('Date')
# Out:
#            Coin    Price     Open     High      Low     Vol. Change %
# Date
# 10/02/2024  ETH  2508.31  2486.24  2514.83  2483.50  504.80K    0.89%
# 9/02/2024   ETH  2486.24  2419.56  2522.96  2419.16  540.92K    2.76%
# 8/02/2024   ETH  2419.56  2424.66  2461.00  2412.01  350.33K   -0.21%
# 7/02/2024   ETH  2424.64  2372.65  2443.71  2354.46  355.40K    2.19%
# 6/02/2024   ETH  2372.65  2301.83  2390.53  2299.24  381.23K    3.08%
# ...         ...      ...      ...      ...      ...      ...      ...
# 5/01/2020   ETH   135.59   134.32   138.33   134.32   12.19M    0.94%
# 4/01/2020   ETH   134.33   134.30   135.57   132.76   11.16M    0.04%
# 3/01/2020   ETH   134.27   127.19   134.86   126.05   15.67M    5.56%
# 2/01/2020   ETH   127.19   130.75   130.77   126.74   11.45M   -2.72%
# 1/01/2020   ETH   130.75   129.21   132.97   128.81   10.35M    1.19%
#
# [1502 rows x 7 columns]

# %%
eth
# Out:
#             Date Coin    Price     Open     High      Low     Vol. Change %
# 0     10/02/2024  ETH  2508.31  2486.24  2514.83  2483.50  504.80K    0.89%
# 1      9/02/2024  ETH  2486.24  2419.56  2522.96  2419.16  540.92K    2.76%
# 2      8/02/2024  ETH  2419.56  2424.66  2461.00  2412.01  350.33K   -0.21%
# 3      7/02/2024  ETH  2424.64  2372.65  2443.71  2354.46  355.40K    2.19%
# 4      6/02/2024  ETH  2372.65  2301.83  2390.53  2299.24  381.23K    3.08%
# ...          ...  ...      ...      ...      ...      ...      ...      ...
# 1497   5/01/2020  ETH   135.59   134.32   138.33   134.32   12.19M    0.94%
# 1498   4/01/2020  ETH   134.33   134.30   135.57   132.76   11.16M    0.04%
# 1499   3/01/2020  ETH   134.27   127.19   134.86   126.05   15.67M    5.56%
# 1500   2/01/2020  ETH   127.19   130.75   130.77   126.74   11.45M   -2.72%
# 1501   1/01/2020  ETH   130.75   129.21   132.97   128.81   10.35M    1.19%
#
# [1502 rows x 8 columns]

# %%
eth.set_index('Date',inplace = True)#reseting index to date

# %%
eth
# Out:
#            Coin    Price     Open     High      Low     Vol. Change %
# Date
# 10/02/2024  ETH  2508.31  2486.24  2514.83  2483.50  504.80K    0.89%
# 9/02/2024   ETH  2486.24  2419.56  2522.96  2419.16  540.92K    2.76%
# 8/02/2024   ETH  2419.56  2424.66  2461.00  2412.01  350.33K   -0.21%
# 7/02/2024   ETH  2424.64  2372.65  2443.71  2354.46  355.40K    2.19%
# 6/02/2024   ETH  2372.65  2301.83  2390.53  2299.24  381.23K    3.08%
# ...         ...      ...      ...      ...      ...      ...      ...
# 5/01/2020   ETH   135.59   134.32   138.33   134.32   12.19M    0.94%
# 4/01/2020   ETH   134.33   134.30   135.57   132.76   11.16M    0.04%
# 3/01/2020   ETH   134.27   127.19   134.86   126.05   15.67M    5.56%
# 2/01/2020   ETH   127.19   130.75   130.77   126.74   11.45M   -2.72%
# 1/01/2020   ETH   130.75   129.21   132.97   128.81   10.35M    1.19%
#
# [1502 rows x 7 columns]

# %%
eth.reset_index()#go back to the orginal
# Out:
#             Date Coin    Price     Open     High      Low     Vol. Change %
# 0     10/02/2024  ETH  2508.31  2486.24  2514.83  2483.50  504.80K    0.89%
# 1      9/02/2024  ETH  2486.24  2419.56  2522.96  2419.16  540.92K    2.76%
# 2      8/02/2024  ETH  2419.56  2424.66  2461.00  2412.01  350.33K   -0.21%
# 3      7/02/2024  ETH  2424.64  2372.65  2443.71  2354.46  355.40K    2.19%
# 4      6/02/2024  ETH  2372.65  2301.83  2390.53  2299.24  381.23K    3.08%
# ...          ...  ...      ...      ...      ...      ...      ...      ...
# 1497   5/01/2020  ETH   135.59   134.32   138.33   134.32   12.19M    0.94%
# 1498   4/01/2020  ETH   134.33   134.30   135.57   132.76   11.16M    0.04%
# 1499   3/01/2020  ETH   134.27   127.19   134.86   126.05   15.67M    5.56%
# 1500   2/01/2020  ETH   127.19   130.75   130.77   126.74   11.45M   -2.72%
# 1501   1/01/2020  ETH   130.75   129.21   132.97   128.81   10.35M    1.19%
#
# [1502 rows x 8 columns]

# %%
eth.sort_index()#sorting index in ascendig order
# Out:
#           Coin    Price     Open     High      Low     Vol. Change %
# Date
# 1/01/2020  ETH   130.75   129.21   132.97   128.81   10.35M    1.19%
# 1/01/2021  ETH   729.12   735.87   748.96   715.74    1.64M   -0.93%
# 1/01/2022  ETH  3765.67  3677.69  3775.20  3675.75  239.54K    2.39%
# 1/01/2023  ETH  1200.52  1195.69  1204.12  1191.67  126.62K    0.41%
# 1/01/2024  ETH  2352.03  2281.89  2352.03  2266.75  229.28K    3.07%
# ...        ...      ...      ...      ...      ...      ...      ...
# 9/11/2023  ETH  2120.16  1888.42  2131.31  1882.91    1.21M   12.22%
# 9/12/2020  ETH   573.21   554.95   577.94   530.88    9.10M    3.27%
# 9/12/2021  ETH  4107.69  4435.74  4482.89  4078.14  642.17K   -7.40%
# 9/12/2022  ETH  1262.86  1280.29  1291.11  1257.00  437.55K   -1.36%
# 9/12/2023  ETH  2340.55  2358.42  2401.34  2332.36  304.64K   -0.76%
#
# [1502 rows x 7 columns]

# %%
eth.sort_values(by = 'Price')
# Out:
#            Coin    Price     Open     High      Low     Vol. Change %
# Date
# 12/03/2020  ETH   107.90   194.57   195.40   102.83   53.51M  -44.55%
# 16/03/2020  ETH   111.02   124.35   124.38   102.44   40.25M  -10.72%
# 17/03/2020  ETH   116.06   111.06   120.60   109.67   27.09M    4.54%
# 18/03/2020  ETH   117.77   115.95   117.91   110.16   25.80M    1.47%
# 22/03/2020  ETH   122.41   132.59   136.86   121.37   25.25M   -7.67%
# ...         ...      ...      ...      ...      ...      ...      ...
# 13/11/2021  ETH  4644.61  4665.76  4705.02  4585.37  290.27K   -0.49%
# 12/11/2021  ETH  4667.31  4720.50  4807.16  4511.96  634.59K   -1.13%
# 11/11/2021  ETH  4720.87  4633.98  4778.17  4578.66  418.61K    1.87%
# 9/11/2021   ETH  4731.83  4808.34  4836.69  4715.43  437.41K   -1.59%
# 8/11/2021   ETH  4808.38  4612.05  4822.97  4612.05  673.21K    4.26%
#
# [1502 rows x 7 columns]

# %%
eth.sort_values(by = 'Price',ascending = False)
# Out:
#            Coin    Price     Open     High      Low     Vol. Change %
# Date
# 8/11/2021   ETH  4808.38  4612.05  4822.97  4612.05  673.21K    4.26%
# 9/11/2021   ETH  4731.83  4808.34  4836.69  4715.43  437.41K   -1.59%
# 11/11/2021  ETH  4720.87  4633.98  4778.17  4578.66  418.61K    1.87%
# 12/11/2021  ETH  4667.31  4720.50  4807.16  4511.96  634.59K   -1.13%
# 13/11/2021  ETH  4644.61  4665.76  4705.02  4585.37  290.27K   -0.49%
# ...         ...      ...      ...      ...      ...      ...      ...
# 22/03/2020  ETH   122.41   132.59   136.86   121.37   25.25M   -7.67%
# 18/03/2020  ETH   117.77   115.95   117.91   110.16   25.80M    1.47%
# 17/03/2020  ETH   116.06   111.06   120.60   109.67   27.09M    4.54%
# 16/03/2020  ETH   111.02   124.35   124.38   102.44   40.25M  -10.72%
# 12/03/2020  ETH   107.90   194.57   195.40   102.83   53.51M  -44.55%
#
# [1502 rows x 7 columns]

# %%
salaries
# Out:
#       work_year experience_level employment_type  \
# 0          2023               EX              FT
# 1          2023               EX              FT
# 2          2023               MI              FT
# 3          2023               MI              FT
# 4          2023               SE              FT
# ...         ...              ...             ...
# 8800       2020               SE              FT
# 8801       2021               MI              FT
# 8802       2020               EN              FT
# 8803       2020               EN              CT
# 8804       2021               SE              FT
#
#                            job_title   salary salary_currency  salary_in_usd  \
# 0              Data Science Director   212000             USD         212000
# 1              Data Science Director   190000             USD         190000
# 2     Business Intelligence Engineer    35000             GBP          43064
# ...

# %%
salaries.sort_values(by = 'salary')
# Out:
#       work_year experience_level employment_type  \
# 8637       2020               EN              PT
# 5282       2020               EX              FT
# 7910       2021               EN              FT
# 3071       2022               MI              FT
# 8207       2022               EN              FT
# ...         ...              ...             ...
# 8039       2022               SE              FT
# 8542       2021               MI              FT
# 8705       2020               MI              FT
# 8635       2021               MI              FT
# 8726       2021               MI              FT
#
#                             job_title    salary salary_currency  \
# 8637                      ML Engineer     14000             EUR
# 5282               Staff Data Analyst     15000             USD
# 7910       Machine Learning Developer     15000             USD
# 3071  Business Intelligence Developer     15000             USD
# ...

# %%
salaries.sort_values(by = 'salary_in_usd', ascending = False)
# Out:
#       work_year experience_level employment_type  \
# 44         2023               EN              FL
# 8587       2020               MI              FT
# 7099       2022               MI              FT
# 5099       2023               MI              FT
# 8797       2021               MI              FT
# ...         ...              ...             ...
# 3332       2023               MI              FT
# 7910       2021               EN              FT
# 8207       2022               EN              FT
# 5282       2020               EX              FT
# 3071       2022               MI              FT
#
#                                job_title  salary salary_currency  \
# 44      Business Intelligence Consultant  500000             GBP
# 8587                  Research Scientist  450000             USD
# 7099                        Data Analyst  350000             GBP
# 5099                  Analytics Engineer  350000             GBP
# ...

# %%
salaries.sort_values(by = ['job_title','salary_in_usd'])
# Out:
#       work_year experience_level employment_type  \
# 432        2023               SE              FT
# 3749       2023               SE              FT
# 2544       2023               SE              FT
# 3358       2023               SE              FT
# 3698       2023               SE              FT
# ...         ...              ...             ...
# 1672       2020               EN              CT
# 4719       2023               MI              FT
# 8690       2021               SE              CT
# 3505       2020               SE              FT
# 3504       2021               SE              FT
#
#                             job_title  salary salary_currency  salary_in_usd  \
# 432                      AI Architect  146900             USD         146900
# 3749                     AI Architect  200000             USD         200000
# 2544                     AI Architect  204000             USD         204000
# ...

# %%
salaries.sort_values(by = ['job_title','salary_in_usd'],ascending =[True,False], inplace =  True)

# %%
salaries
# Out:
#       work_year experience_level employment_type  \
# 2543       2023               SE              FT
# 3357       2023               SE              FT
# 3697       2023               SE              FT
# 3895       2023               SE              FT
# 431        2023               SE              FT
# ...         ...              ...             ...
# 1672       2020               EN              CT
# 5282       2020               EX              FT
# 3505       2020               SE              FT
# 8690       2021               SE              CT
# 3504       2021               SE              FT
#
#                             job_title  salary salary_currency  salary_in_usd  \
# 2543                     AI Architect  330000             USD         330000
# 3357                     AI Architect  330000             USD         330000
# 3697                     AI Architect  330000             USD         330000
# ...

# %%
eth
# Out:
#            Coin    Price     Open     High      Low     Vol. Change %
# Date
# 10/02/2024  ETH  2508.31  2486.24  2514.83  2483.50  504.80K    0.89%
# 9/02/2024   ETH  2486.24  2419.56  2522.96  2419.16  540.92K    2.76%
# 8/02/2024   ETH  2419.56  2424.66  2461.00  2412.01  350.33K   -0.21%
# 7/02/2024   ETH  2424.64  2372.65  2443.71  2354.46  355.40K    2.19%
# 6/02/2024   ETH  2372.65  2301.83  2390.53  2299.24  381.23K    3.08%
# ...         ...      ...      ...      ...      ...      ...      ...
# 5/01/2020   ETH   135.59   134.32   138.33   134.32   12.19M    0.94%
# 4/01/2020   ETH   134.33   134.30   135.57   132.76   11.16M    0.04%
# 3/01/2020   ETH   134.27   127.19   134.86   126.05   15.67M    5.56%
# 2/01/2020   ETH   127.19   130.75   130.77   126.74   11.45M   -2.72%
# 1/01/2020   ETH   130.75   129.21   132.97   128.81   10.35M    1.19%
#
# [1502 rows x 7 columns]

# %%
eth.loc[['25/05/2021','25/12/2022','25/12/2023','25/12/2020']]#specify the label u want to view
# Out:
#            Coin    Price     Open     High      Low     Vol. Change %
# Date
# 25/05/2021  ETH  2705.09  2647.27  2747.49  2388.81    3.28M    2.20%
# 25/12/2022  ETH  1218.69  1220.46  1223.82  1201.20  256.52K   -0.15%
# 25/12/2023  ETH  2271.38  2263.57  2303.28  2253.25  298.17K    0.35%
# 25/12/2020  ETH   626.93   612.38   633.90   605.01    1.70M    2.38%

# %%
eth.loc[['25/05/2021','25/12/2022','25/12/2023','25/12/2020'],['Price','High']]
# Out:
#               Price     High
# Date
# 25/05/2021  2705.09  2747.49
# 25/12/2022  1218.69  1223.82
# 25/12/2023  2271.38  2303.28
# 25/12/2020   626.93   633.90

# %%
salaries
# Out:
#       work_year experience_level employment_type  \
# 2543       2023               SE              FT
# 3357       2023               SE              FT
# 3697       2023               SE              FT
# 3895       2023               SE              FT
# 431        2023               SE              FT
# ...         ...              ...             ...
# 1672       2020               EN              CT
# 5282       2020               EX              FT
# 3505       2020               SE              FT
# 8690       2021               SE              CT
# 3504       2021               SE              FT
#
#                             job_title  salary salary_currency  salary_in_usd  \
# 2543                     AI Architect  330000             USD         330000
# 3357                     AI Architect  330000             USD         330000
# 3697                     AI Architect  330000             USD         330000
# ...

# %%
airbnb
# Out:
#         Host Id  Host Since                                Name Neighbourhood  \
# 0       5162530         NaN     1 Bedroom in Prime Williamsburg      Brooklyn
# 1      33134899         NaN     Sunny, Private room in Bushwick      Brooklyn
# 2      39608626         NaN                Sunny Room in Harlem     Manhattan
# 3           500  26/06/2008  Gorgeous 1 BR with Private Balcony     Manhattan
# 4           500  26/06/2008            Trendy Times Square Loft     Manhattan
# ...         ...         ...                                 ...           ...
# 30473  43022976  31/08/2015   10 Mins to Time Square/two floors        Queens
# 30474  42993382  31/08/2015       1BR ocean view & F,Q train st      Brooklyn
# 30475  43033067  31/08/2015                Amazing Private Room      Brooklyn
# 30476  43000991  31/08/2015   Charming private female room: UWS     Manhattan
# 30477  42999189  31/08/2015    Huge Beautiful Bedroom - Astoria        Queens
#
# ...

# %%
airbnb.iloc[50]#Purely integer-location based indexing for selection by position.
# Out:
# Host Id                                                     5926
# Host Since                                             2/01/2009
# Name                          Nice  Apt Near Columbia University
# Neighbourhood                                          Manhattan
# Property Type                                    Bed & Breakfast
# Review Scores Rating (bin)                                  85.0
# Room Type                                           Private room
# Zipcode                                                  10031.0
# Beds                                                         1.0
# Number of Records                                              1
# Number Of Reviews                                             68
# Price                                                         55
# Review Scores Rating                                        86.0
# Name: 50, dtype: object

# %%
salaries['salary_in_usd'].value_counts().loc[150000]
# Out:
# 188

# %%
world
# Out:
#      Overall rank  Year         Country or region  Score  GDP per capita  \
# 0               1  2019                   Finland  7.769           1.340
# 1               2  2019                   Denmark  7.600           1.383
# 2               3  2019                    Norway  7.554           1.488
# 3               4  2019                   Iceland  7.494           1.380
# 4               5  2019               Netherlands  7.488           1.396
# ..            ...   ...                       ...    ...             ...
# 307           152  2018                     Yemen  3.355           0.442
# 308           153  2018                  Tanzania  3.303           0.455
# 309           154  2018               South Sudan  3.254           0.337
# 310           155  2018  Central African Republic  3.083           0.024
# 311           156  2018                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# ...

# %%
world = world.set_index('Country or region').sort_values(by='Country or region')

# %%
world.loc['Ireland']
# Out:
#                    Overall rank  Year  Score  GDP per capita  Social support  \
# Country or region
# Ireland                      16  2019  7.021           1.499           1.553
# Ireland                      14  2018  6.977           1.448           1.583
#
#                    Healthy life expectancy  Freedom to make life choices  \
# Country or region
# Ireland                              0.999                         0.516
# Ireland                              0.876                         0.614
#
#                    Generosity  Perceptions of corruption
# Country or region
# Ireland                 0.298                      0.310
# Ireland                 0.307                      0.306

# %%
world.loc['Canada']
# Out:
#                    Overall rank  Year  Score  GDP per capita  Social support  \
# Country or region
# Canada                        7  2018  7.328           1.330           1.532
# Canada                        9  2019  7.278           1.365           1.505
#
#                    Healthy life expectancy  Freedom to make life choices  \
# Country or region
# Canada                               0.896                         0.653
# Canada                               1.039                         0.584
#
#                    Generosity  Perceptions of corruption
# Country or region
# Canada                  0.321                      0.291
# Canada                  0.285                      0.308

# %%
world = world.reset_index()

# %%
world = world.set_index(['Country or region','Year'])

# %%
world
# Out:
#                         Overall rank  Score  GDP per capita  Social support  \
# Country or region Year
# Afghanistan       2019           154  3.203           0.350           0.517
#                   2018           145  3.632           0.332           0.537
# Albania           2018           112  4.586           0.916           0.817
#                   2019           107  4.719           0.947           0.848
# Algeria           2018            84  5.295           0.979           1.154
# ...                              ...    ...             ...             ...
# Yemen             2018           152  3.355           0.442           1.073
# Zambia            2019           138  4.107           0.578           1.058
#                   2018           125  4.377           0.562           1.047
# Zimbabwe          2019           146  3.663           0.366           1.114
#                   2018           144  3.692           0.357           1.094
#
# ...

# %%
world.loc['Canada', 2018]
# Out:
# Overall rank                    7.000
# Score                           7.328
# GDP per capita                  1.330
# Social support                  1.532
# Healthy life expectancy         0.896
# Freedom to make life choices    0.653
# Generosity                      0.321
# Perceptions of corruption       0.291
# Name: (Canada, 2018), dtype: float64

# %%
airbnb.loc[10:100]
# Out:
#      Host Id  Host Since                                 Name Neighbourhood  \
# 10      2571  27/08/2008                           THE PUTNAM      Brooklyn
# 11      2758   6/09/2008     Stay at Chez Chic budget room #1     Manhattan
# 12      2758   6/09/2008     Stay at Chez Chic budget Room #2     Manhattan
# 13      2787   7/09/2008      Renovated and spacious townhome      Brooklyn
# 14      2845   9/09/2008                       Midtown Castle     Manhattan
# ..       ...         ...                                  ...           ...
# 96      8380  22/02/2009            River view in the Village     Manhattan
# 97      8440  23/02/2009    Beautiful studio by Prospect Park      Brooklyn
# 98      8440  23/02/2009  Luxe 1BD apartment by Prospect Park      Brooklyn
# 99      8425  23/02/2009    Charming W.Village Apt. 8/25-9/15     Manhattan
# 100     8605  25/02/2009      Sunny 1BR East Harlem Apartment     Manhattan
#
# ...

# %%
world = world.reset_index()

# %%
world
# Out:
#     Country or region  Year  Overall rank  Score  GDP per capita  \
# 0         Afghanistan  2019           154  3.203           0.350
# 1         Afghanistan  2018           145  3.632           0.332
# 2             Albania  2018           112  4.586           0.916
# 3             Albania  2019           107  4.719           0.947
# 4             Algeria  2018            84  5.295           0.979
# ..                ...   ...           ...    ...             ...
# 307             Yemen  2018           152  3.355           0.442
# 308            Zambia  2019           138  4.107           0.578
# 309            Zambia  2018           125  4.377           0.562
# 310          Zimbabwe  2019           146  3.663           0.366
# 311          Zimbabwe  2018           144  3.692           0.357
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             0.517                    0.361                         0.000
# ...

# %%
world = world.reset_index()

# %%
world.set_index('Overall rank').sort_index().loc[1:10]
# Out:
#               index Country or region  Year  Score  GDP per capita  \
# Overall rank
# 1                87           Finland  2018  7.632           1.305
# 1                88           Finland  2019  7.769           1.340
# 2                73           Denmark  2019  7.600           1.383
# 2               211            Norway  2018  7.594           1.456
# 3                74           Denmark  2018  7.555           1.351
# 3               210            Norway  2019  7.554           1.488
# 4               114           Iceland  2019  7.494           1.380
# 4               115           Iceland  2018  7.495           1.343
# 5               198       Netherlands  2019  7.488           1.396
# 5               266       Switzerland  2018  7.487           1.420
# 6               267       Switzerland  2019  7.480           1.452
# 6               197       Netherlands  2018  7.441           1.361
# 7                48            Canada  2018  7.328           1.330
# ...

# %%
world
# Out:
#      Overall rank  index Country or region  Year  Score  GDP per capita  \
# 0             154      0       Afghanistan  2019  3.203           0.350
# 1             145      1       Afghanistan  2018  3.632           0.332
# 2             112      2           Albania  2018  4.586           0.916
# 3             107      3           Albania  2019  4.719           0.947
# 4              84      4           Algeria  2018  5.295           0.979
# ..            ...    ...               ...   ...    ...             ...
# 307           152    307             Yemen  2018  3.355           0.442
# 308           138    308            Zambia  2019  4.107           0.578
# 309           125    309            Zambia  2018  4.377           0.562
# 310           146    310          Zimbabwe  2019  3.663           0.366
# 311           144    311          Zimbabwe  2018  3.692           0.357
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# ...

# %%
top_10_happy = world.set_index('Overall rank').sort_index().loc[1:10]

# %%
top_10_happy
# Out:
#               index Country or region  Year  Score  GDP per capita  \
# Overall rank
# 1                87           Finland  2018  7.632           1.305
# 1                88           Finland  2019  7.769           1.340
# 2                73           Denmark  2019  7.600           1.383
# 2               211            Norway  2018  7.594           1.456
# 3                74           Denmark  2018  7.555           1.351
# 3               210            Norway  2019  7.554           1.488
# 4               114           Iceland  2019  7.494           1.380
# 4               115           Iceland  2018  7.495           1.343
# 5               198       Netherlands  2019  7.488           1.396
# 5               266       Switzerland  2018  7.487           1.420
# 6               267       Switzerland  2019  7.480           1.452
# 6               197       Netherlands  2018  7.441           1.361
# 7                48            Canada  2018  7.328           1.330
# ...

# %%
world
# Out:
#      Overall rank  index Country or region  Year  Score  GDP per capita  \
# 0             154      0       Afghanistan  2019  3.203           0.350
# 1             145      1       Afghanistan  2018  3.632           0.332
# 2             112      2           Albania  2018  4.586           0.916
# 3             107      3           Albania  2019  4.719           0.947
# 4              84      4           Algeria  2018  5.295           0.979
# ..            ...    ...               ...   ...    ...             ...
# 307           152    307             Yemen  2018  3.355           0.442
# 308           138    308            Zambia  2019  4.107           0.578
# 309           125    309            Zambia  2018  4.377           0.562
# 310           146    310          Zimbabwe  2019  3.663           0.366
# 311           144    311          Zimbabwe  2018  3.692           0.357
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# ...

# %%
salaries
# Out:
#       work_year experience_level employment_type  \
# 2543       2023               SE              FT
# 3357       2023               SE              FT
# 3697       2023               SE              FT
# 3895       2023               SE              FT
# 431        2023               SE              FT
# ...         ...              ...             ...
# 1672       2020               EN              CT
# 5282       2020               EX              FT
# 3505       2020               SE              FT
# 8690       2021               SE              CT
# 3504       2021               SE              FT
#
#                             job_title  salary salary_currency  salary_in_usd  \
# 2543                     AI Architect  330000             USD         330000
# 3357                     AI Architect  330000             USD         330000
# 3697                     AI Architect  330000             USD         330000
# ...

# %%
salaries['job_title'].value_counts()
# Out:
# job_title
# Data Engineer                           2062
# Data Scientist                          1852
# Data Analyst                            1322
# Machine Learning Engineer                908
# Applied Scientist                        258
#                                         ...
# Manager Data Management                    1
# Data DevOps Engineer                       1
# Machine Learning Operations Engineer       1
# Data Science Tech Lead                     1
# Staff Machine Learning Engineer            1
# Name: count, Length: 124, dtype: int64

# %%
pd.DataFrame(salaries['job_title'].value_counts())
# Out:
#                                       count
# job_title
# Data Engineer                          2062
# Data Scientist                         1852
# Data Analyst                           1322
# Machine Learning Engineer               908
# Applied Scientist                       258
# ...                                     ...
# Manager Data Management                   1
# Data DevOps Engineer                      1
# Machine Learning Operations Engineer      1
# Data Science Tech Lead                    1
# Staff Machine Learning Engineer           1
#
# [124 rows x 1 columns]

# %%
top_20_jobs = pd.DataFrame(salaries['job_title'].value_counts().head(10))

# %%
top_20_jobs.plot()
# Out:
# <Axes: xlabel='job_title'>

# %%
top_20_jobs.plot(kind='bar')
# Out:
# <Axes: xlabel='job_title'>

# %%
top_20_jobs.sort_values(by  ='count').plot(kind='bar')
# Out:
# <Axes: xlabel='job_title'>

# %%
top_20_jobs.sort_values(by = 'count').plot(kind='barh', color = 'red')
# Out:
# <Axes: ylabel='job_title'>

# %%
salaries['experience_level'].value_counts()
# Out:
# experience_level
# SE    6336
# MI    1732
# EN     468
# EX     269
# Name: count, dtype: int64

# %%
salaries['experience_level'].value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>
